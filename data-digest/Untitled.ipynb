# %%
import os 
import pandas as pd
import json

# %%
def digest(file):
    f = open(file, 'r')
    data = [json.loads(line) for line in open(file, 'r')]
    #df = pd.read_json(file, lines=True)
    return data

# %%
entries = [digest(entry) for entry in os.scandir('../../data/') if entry.is_file()]

# %%
entries[0][0]['features']
# Out:
# [{'geometry': {'coordinates': [14.52685, 50.03045], 'type': 'Point'},
#   'properties': {'trip': {'cis_agency_name': 'ČSAD POLKOST',
#     'cis_id': '100381',
#     'cis_number': 54,
#     'cis_order': 6,
#     'cis_parent_route_name': '381',
#     'cis_real_agency_name': 'ČSAD POLKOST',
#     'cis_short_name': '381',
#     'cis_vehicle_registration_number': 1869,
#     'gtfs_route_id': 'L381',
#     'gtfs_route_short_name': '381',
#     'gtfs_trip_id': '381_282_190701',
#     'id': '2019-08-12T18:15:00Z_100381_381_54',
#     'start_cis_stop_id': 17158,
#     'start_cis_stop_platform_code': '7',
#     'start_time': '20:15:00',
#     'start_timestamp': '2019-08-12T18:15:00.000Z',
#     'vehicle_type': 4,
#     'wheelchair_accessible': True},
#    'last_position': {'bearing': 259,
#     'cis_last_stop_id': 55083,
#     'cis_last_stop_sequence': 42,
#     'delay': 101,
#     'delay_stop_arrival': 90,
#     'delay_stop_departure': None,
#     'gtfs_last_stop_id': None,
# ...
